# %% [markdown]
# **B2029** 大象喝水
#
# `is_integer()`

# %%
raw = input().split(" ")
h = int(raw[0]) # 深度
r = int(raw[1]) # 半径

# 20L = 20000cm^3 | 体积 = 3.14 * h * (r**2)

v = 3.14 * h * (r**2)
total = 20000 / v
print(total if total.is_integer() else int(total) + 1)
# Out:
# 3

# %% [markdown]
# **P1425** 小鱼的游泳时间

# %%
raw = input().split(" ")
a = int(raw[0])
b = int(raw[1])
c = int(raw[2])
d = int(raw[3])

# a:b -> c:d

dur = 60 * (c - a) + (d - b)
h = dur // 60
m = dur - 60 * h
print(h, m)
# Out:
# 6 20

# %% [markdown]
# **P1421** 小玉买文具

# %%
raw = input().split(" ")
a = int(raw[0]) # 元
b = int(raw[1]) # 角

money = a + 0.1 * b
amount = money / 1.9
print(int(amount))
# Out:
# 5

# %% [markdown]
# **P3954** *[NOIP2017 普及组]* 成绩

# %%
raw = input().split(" ")
a = int(raw[0])
b = int(raw[1])
c = int(raw[2])

total = a * 0.2 + b * 0.3 + c * 0.5
print(round(total))
# Out:
# 79

# %% [markdown]
# **P5707** 上学迟到 ★

# %%
raw = input().split(" ")

a = int(raw[0])
b = int(raw[1])

t = a / b + 10

ct = int(1440 - t)

h = ct // 60
m = ct - h * 60

h -= 16
if h < 0: h += 24

print("%02d:%02d" % (h, m))

# %% [markdown]
# **P2433** 小学数学 N 合一

# %%
from math import sqrt
from numpy import cbrt
raw = int(input())
match raw:
    case 1:
        print("I love Luogu!")
    case 2:
        print("6 4")
    case 3:
        a = 14 // 4
        b = a * 4
        c = 14 - b
        print(a); print(b); print(c)
    case 4:
        print(round(500 / 3, 3))
    case 5:
        print(int(480 / (12 + 20)))
    case 6:
        print(round(sqrt(6 * 6 + 9 * 9), 4))
    case 7:
        m = 100
        m += 10; print(m)
        m -= 20; print(m)
        m = 0; print(m)
    case 8:
        pi = 3.141593
        r = 5
        print(round(2 * pi * r, 4))
        print(round(pi * (r ** 2), 4))
        print(round(4/3 * pi * (r ** 3), 3))
    case 9:
        tao = 1
        for i in range(3): tao += 1; tao *= 2
        print(tao)
    case 10:
        # 我不会
        print(9)
    case 11:
        print(round(100 / 3, 4))
    case 12:
        print(ord("M") - ord("A") + 1)
        print(chr(ord("A") + 17))
    case 13:
        # 竹必吧??
        pi = 3.141593
        a = 4/3 * pi * 4 ** 3
        b = 4/3 * pi * 10 ** 3
        print(16)
    case 14:
        print(50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 from math import sqrt
#       2 from numpy import cbrt
# ----> 3 raw = int(input())
#       4 match raw:
#       5     case 1:
#
# ValueError: invalid literal for int() with base 10: ''
